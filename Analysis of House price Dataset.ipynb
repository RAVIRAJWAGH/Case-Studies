# %% [markdown]
# ## Name: Raviraj Wagh

# %% [markdown]
# ## Working with 'House price' Dataset

# %%
import numpy as np
import pandas as pd

# %%
data1=pd.read_csv(r"C:\Users\Parimal\Downloads\HousePrice.csv")
data1
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
data1.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   ADDRESS                29451 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %% [markdown]
# #### Q1) Find the oweners and buiders whose target price balow 60 lacs but they should aproved by RERA

# %%
data1["POSTED_BY"].unique()
# Out:
# array(['Owner', 'Dealer', 'Builder'], dtype=object)

# %%
data1.loc[((data1["POSTED_BY"]=="Owner")|(data1["POSTED_BY"]=="Builder"))&(data1["TARGET(PRICE_IN_LACS)"]<60)&(data1["RERA"]==1)]
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 7         Owner                   0     1        3       BHK  1181.012946
# 9         Owner                   0     1        2       BHK   879.120879
# 48      Builder                   1     1        1       BHK   301.917116
# 100       Owner                   1     1        2       BHK   989.902989
# 122       Owner                   1     1        2       BHK  1109.165207
# ...         ...                 ...   ...      ...       ...          ...
# 29407     Owner                   0     1        3       BHK  1463.679075
# 29416     Owner                   0     1        1       BHK   550.055005
# 29429   Builder                   0     1        2       BHK   974.930362
# 29438   Builder                   1     1        3       BHK  1560.000000
# 29440   Builder                   0     1        3       BHK  1652.634861
#
#        READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# #### Q2)Find the 2BHK owners but target price should 60-90 and that should be ready to move.

# %%
data1.loc[(data1["BHK_NO."]==2)&(data1["BHK_OR_RK"]=="BHK")&(data1["POSTED_BY"]=="Owner")&((data1["TARGET(PRICE_IN_LACS)"]>=60)&(data1["TARGET(PRICE_IN_LACS)"]<90))&(data1["READY_TO_MOVE"]==1)]
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 3         Owner                   0     1        2       BHK   929.921143
# 13        Owner                   0     1        2       BHK  1122.171946
# 56        Owner                   0     0        2       BHK   950.014616
# 68        Owner                   0     0        2       BHK  5000.000000
# 71        Owner                   0     0        2       BHK   760.070940
# ...         ...                 ...   ...      ...       ...          ...
# 29195     Owner                   0     0        2       BHK   800.000000
# 29310     Owner                   0     0        2       BHK  1345.390384
# 29338     Owner                   0     0        2       BHK  1216.022890
# 29359     Owner                   0     0        2       BHK  1423.324151
# 29449     Owner                   0     0        2       BHK   927.079009
#
#        READY_TO_MOVE  RESALE                        ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# #### Q3)Find the owners whose flates under construction but this flates approved by RERA, show the target price.

# %%
data1.loc[(data1["POSTED_BY"]=="Owner")&(data1["UNDER_CONSTRUCTION"]==1)&(data1["RERA"]==1),["POSTED_BY","TARGET(PRICE_IN_LACS)"]]
# Out:
#       POSTED_BY  TARGET(PRICE_IN_LACS)
# 100       Owner                   50.0
# 122       Owner                   38.0
# 161       Owner                  250.0
# 684       Owner                   41.0
# 888       Owner                   69.3
# ...         ...                    ...
# 29202     Owner                   19.9
# 29322     Owner                   46.0
# 29326     Owner                   78.0
# 29360     Owner                   37.0
# 29436     Owner                   62.0
#
# [286 rows x 2 columns]

# %% [markdown]
# #### 4)Find owners and dealers whose flate size below 900 sq.feet and increase the target price upto 5 lacs

# %%
a=data1.loc[((data1["POSTED_BY"]=="Owner")|(data1["POSTED_BY"]=="Dealer"))&(data1["SQUARE_FT"]<900)&(data1["TARGET(PRICE_IN_LACS)"]<5)]

# %% [markdown]
# #### 5)Find the dealer those are having RERA approved and if that the size of 2BHK then decrease by 2 lacs and above the 2BHK then increase the target price upto 7 lacs

# %%
b=data1.loc[(data1["POSTED_BY"]=="Dealer")&(data1["RERA"]==1)]
b
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 8        Dealer                   0     1        2       BHK  1040.000000
# 15       Dealer                   1     1        3       BHK  1394.117647
# 17       Dealer                   1     1        3       BHK  2124.896706
# 19       Dealer                   0     1        3       BHK  2178.649237
# 22       Dealer                   0     1        3       BHK  1310.147689
# ...         ...                 ...   ...      ...       ...          ...
# 29435    Dealer                   0     1        4       BHK  2189.160468
# 29439    Dealer                   1     1        2       BHK   975.609756
# 29443    Dealer                   0     1        3       BHK  1161.194975
# 29444    Dealer                   1     1        1       BHK   752.049334
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                 ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# #### 5)Find the dealer those are having RERA approved and if that the size of 2BHK then decrease by 2 lacs and above the 2BHK then increase the target price upto 7 lacs

# %%
new_target=[]
for i in range(len(b)):
    if b.iloc[i,3]==2:
        new_target.append((b.iloc[i,11]-2))
    elif b.iloc[i,3]<2:
        new_target.append((b.iloc[i,11]))
    else:
        new_target.append((b.iloc[i,11]+7))

# %%
b["new_target"]=new_target
# Out:
# C:\Users\Parimal\AppData\Local\Temp/ipykernel_22604/2175052837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b["new_target"]=new_target

# %%
b
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 8        Dealer                   0     1        2       BHK  1040.000000
# 15       Dealer                   1     1        3       BHK  1394.117647
# 17       Dealer                   1     1        3       BHK  2124.896706
# 19       Dealer                   0     1        3       BHK  2178.649237
# 22       Dealer                   0     1        3       BHK  1310.147689
# ...         ...                 ...   ...      ...       ...          ...
# 29435    Dealer                   0     1        4       BHK  2189.160468
# 29439    Dealer                   1     1        2       BHK   975.609756
# 29443    Dealer                   0     1        3       BHK  1161.194975
# 29444    Dealer                   1     1        1       BHK   752.049334
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                 ADDRESS  LONGITUDE   LATITUDE  \
# ...
