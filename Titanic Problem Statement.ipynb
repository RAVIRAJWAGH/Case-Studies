# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# 1)Find Females those who are not alone with fare value is less then 60,000 and greather then 20,000
# 2)find te Third class travled peoples and find the count of teenage and Adult_age and Old age 
# 3)find the count of teenage and Adult_age and Old age 
# 4)Find Alive Man and childs from 1st and second class with fare of above 25000

# %%
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
from numpy import mean

# %%
m=mean(titanic["age"])
titanic["age"]=titanic["age"].fillna(m)

# %%
titanic["age"].isnull().sum()
# Out:
# 0

# %%
# 1)Find Females those who are not alone with fare value is less then 60,000 and greather then 20,000

# %%
q1=titanic.loc[(titanic["sex"]=="female")&(titanic["alone"]==False)&((titanic["fare"]>20.0000)&(titanic["fare"]<60.0000))]
q1
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 3           1       1  female  35.000000      1      0  53.1000        S
# 9           1       2  female  14.000000      1      0  30.0708        C
# 24          0       3  female   8.000000      3      1  21.0750        S
# 25          1       3  female  38.000000      1      5  31.3875        S
# 41          0       2  female  27.000000      1      0  21.0000        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 871         1       1  female  47.000000      1      1  52.5542        S
# 874         1       2  female  28.000000      1      0  24.0000        C
# 880         1       2  female  25.000000      0      1  26.0000        S
# 885         0       3  female  39.000000      0      5  29.1250        Q
# 888         0       3  female  29.699118      1      2  23.4500        S
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic["who"].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
# 2)find te Third class travled peoples and find the count of teenage and Adult_age and Old age 
titanic.loc[(titanic["class"]=="Third")&((titanic["age"]>=15)&(titanic["age"]<=20))].shape
# Out:
# (69, 15)

# %%
titanic.loc[(titanic["class"]=="Third")&((titanic["age"]>=20)&(titanic["age"]<60))].shape
# Out:
# (378, 15)

# %%
titanic.loc[(titanic["class"]=="Third")&(titanic["age"]>60)].shape
# Out:
# (5, 15)

# %%
# 3)find the count of teenage and Adult_age and Old age 
print("count of teen_age peaples are :",titanic.loc[(titanic["age"]>=15)&(titanic["age"]<20)].shape)
print("count of adult_age peaples are :",titanic.loc[(titanic["age"]>=20)&(titanic["age"]<60)].shape)
print("count of old_age peaples are :",titanic.loc[(titanic["age"]>=60)].shape)
# Out:
# count of teen_age peaples are : (86, 15)
# count of adult_age peaples are : (701, 15)
# count of old_age peaples are : (26, 15)

# %%
# 4)Find Alive Man and childs from 1st and second class with fare of above 25000

# %%
titanic.loc[(titanic["alive"]=="yes")&((titanic["who"]=="child")|(titanic["who"]=="men"))&(titanic["fare"]>25)]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 43          1       2  female   3.00      1      2   41.5792        C  Second
# 58          1       2  female   5.00      1      2   27.7500        S  Second
# 78          1       2    male   0.83      0      2   29.0000        S  Second
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 193         1       2    male   3.00      1      1   26.0000        S  Second
# 233         1       3  female   5.00      4      2   31.3875        S   Third
# 237         1       2  female   8.00      0      2   26.2500        S  Second
# 261         1       3    male   3.00      4      2   31.3875        S   Third
# 305         1       1    male   0.92      1      2  151.5500        S   First
# 340         1       2    male   2.00      1      1   26.0000        S  Second
# ...
