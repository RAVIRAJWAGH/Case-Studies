# %% [markdown]
# ## Name: Raviraj Wagh

# %% [markdown]
# # Working with "Brain Stroke" Dataset

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Parimal\Downloads\Brain Stroke.csv")
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
print(data["age"].min())
print(data["age"].max())
# Out:
# 0.08
# 82.0

# %% [markdown]
# #### Q1) Find the male and female those age are below 50 and they are working as self employed and govt job

# %%
a=data.loc[(data["age"]<=50)&(((data["work_type"]=="Self-employed")|(data["work_type"]=="Govt_job")))]
a
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 12    Female  50.0             1              0          Yes  Self-employed
# 28      Male  48.0             0              0           No       Govt_job
# 64      Male  43.0             0              0          Yes  Self-employed
# 98    Female  38.0             0              0           No  Self-employed
# 188   Female  39.0             0              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 4940  Female  41.0             0              0          Yes  Self-employed
# 4949  Female  37.0             0              0           No       Govt_job
# 4950    Male  32.0             1              0           No       Govt_job
# 4963  Female  20.0             0              0           No       Govt_job
# 4978  Female  45.0             1              0          Yes       Govt_job
#
# ...

# %%
a.count()
# Out:
# gender               535
# age                  535
# hypertension         535
# heart_disease        535
# ever_married         535
# work_type            535
# Residence_type       535
# avg_glucose_level    535
# bmi                  535
# smoking_status       535
# stroke               535
# dtype: int64

# %% [markdown]
# #### Q2) Find the Females those are facing heart disease and those BMI are between 20-35

# %%
b=data.loc[((data["gender"]=="Female")&(data["heart_disease"]==1)&((data["bmi"]>=25)&(data["bmi"]<=35)))]
b
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 11    Female  79.0             0              1          Yes        Private
# 29    Female  82.0             1              1           No        Private
# 42    Female  79.0             0              1          Yes        Private
# 70    Female  70.0             0              1          Yes        Private
# 73    Female  79.0             0              1          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4955  Female  69.0             0              1          Yes        Private
# 4966  Female  65.0             0              1          Yes        Private
# 4968  Female  78.0             1              1          Yes        Private
# 4969  Female  70.0             0              1          Yes  Self-employed
# 4970  Female  70.0             0              1          Yes  Self-employed
#
# ...

# %%
b.count()
# Out:
# gender               71
# age                  71
# hypertension         71
# heart_disease        71
# ever_married         71
# work_type            71
# Residence_type       71
# avg_glucose_level    71
# bmi                  71
# smoking_status       71
# stroke               71
# dtype: int64

# %% [markdown]
# #### Q3) Create new colomn of given categories

# %%
abc=[]
for x in data["age"]:
    if x<=15:
        abc.append("kid")
    elif x>15 and x<=30:
        abc.append("teenage")
    elif x>30 and x<=50:
        abc.append("adult")
    else:
        abc.append("old_age")

# %%
data.insert(2,"age_group",abc)

# %%
data
# Out:
#       gender   age age_group  hypertension  heart_disease ever_married  \
# 0       Male  67.0   old_age             0              1          Yes
# 1       Male  80.0   old_age             0              1          Yes
# 2     Female  49.0     adult             0              0          Yes
# 3     Female  79.0   old_age             1              0          Yes
# 4       Male  81.0   old_age             0              0          Yes
# ...      ...   ...       ...           ...            ...          ...
# 4976    Male  41.0     adult             0              0           No
# 4977    Male  40.0     adult             0              0          Yes
# 4978  Female  45.0     adult             1              0          Yes
# 4979    Male  40.0     adult             0              0          Yes
# 4980  Female  80.0   old_age             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# #### Q4) Find old_age peaple those smoking continueous and average glucose level  above 150

# %%
data["smoking_status"].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
d=data.loc[(data["age_group"]=="old_age")&(data["smoking_status"]=="smokes")&(data["avg_glucose_level"]>150)]
d
# Out:
#       gender   age age_group  hypertension  heart_disease ever_married  \
# 13      Male  64.0   old_age             0              1          Yes
# 14      Male  75.0   old_age             1              0          Yes
# 16    Female  71.0   old_age             0              0          Yes
# 23      Male  69.0   old_age             0              1          Yes
# 24      Male  57.0   old_age             1              0          Yes
# ...      ...   ...       ...           ...            ...          ...
# 4898    Male  78.0   old_age             0              1          Yes
# 4912    Male  75.0   old_age             1              0          Yes
# 4951  Female  79.0   old_age             0              0          Yes
# 4970  Female  70.0   old_age             0              1          Yes
# 4972    Male  72.0   old_age             0              1          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
d.count()
# Out:
# gender               75
# age                  75
# age_group            75
# hypertension         75
# heart_disease        75
# ever_married         75
# work_type            75
# Residence_type       75
# avg_glucose_level    75
# bmi                  75
# smoking_status       75
# stroke               75
# dtype: int64

# %% [markdown]
# #### Q5) Find the Adult and oldage Female those are working in private company and are from urban area

# %%
e=data.loc[((data["age_group"]=="adult")|(data["age_group"]=="old_age"))&(data["gender"]=="Female")&(data["work_type"]=="Private")&(data["Residence_type"]=="Urban")]
e
# Out:
#       gender   age age_group  hypertension  heart_disease ever_married  \
# 2     Female  49.0     adult             0              0          Yes
# 6     Female  69.0   old_age             0              0           No
# 7     Female  78.0   old_age             0              0          Yes
# 10    Female  54.0   old_age             0              0          Yes
# 11    Female  79.0   old_age             0              1          Yes
# ...      ...   ...       ...           ...            ...          ...
# 4936  Female  33.0     adult             0              0           No
# 4944  Female  45.0     adult             0              0          Yes
# 4955  Female  69.0   old_age             0              1          Yes
# 4957  Female  82.0   old_age             1              0          Yes
# 4980  Female  80.0   old_age             1              0          Yes
#
#      work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# #### Q6)  Find self employed peaples those are never smoked but have brain strock problem with glucose 0-75, 75-150, 150-above
# #### a) 0-75

# %%
f=data.loc[(data["work_type"]=="Self-employed")&(data["smoking_status"]=="never smoked")&(data["stroke"]==1)&(data["avg_glucose_level"]<75)]
f
# Out:
#       gender   age age_group  hypertension  heart_disease ever_married  \
# 56    Female  80.0   old_age             1              0          Yes
# 75    Female  57.0   old_age             0              0           No
# 119   Female  69.0   old_age             1              1           No
# 133   Female  81.0   old_age             1              0          Yes
# 162   Female  74.0   old_age             0              0          Yes
# 192   Female  73.0   old_age             0              0          Yes
# 4810  Female  79.0   old_age             1              1           No
# 4818    Male  74.0   old_age             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 56    Self-employed          Rural              72.67  28.9   never smoked
# 75    Self-employed          Urban              68.02  37.5   never smoked
# 119   Self-employed          Urban              72.17  36.8   never smoked
# ...

# %% [markdown]
# #### Q6)
# #### b) 75-150

# %%
g=data.loc[(data["work_type"]=="Self-employed")&(data["smoking_status"]=="never smoked")&(data["stroke"]==1)&((data["avg_glucose_level"]>=75)&(data["avg_glucose_level"]<150))]
g
# Out:
#      gender   age age_group  hypertension  heart_disease ever_married  \
# 21     Male  80.0   old_age             0              0          Yes
# 40     Male  81.0   old_age             0              0          Yes
# 43   Female  77.0   old_age             1              0          Yes
# 67   Female  68.0   old_age             1              0           No
# 126  Female  80.0   old_age             0              0          Yes
# 128  Female  55.0   old_age             0              0          Yes
# 139    Male  81.0   old_age             0              0          Yes
# 164  Female  77.0   old_age             0              0          Yes
# 165  Female  78.0   old_age             0              0          Yes
# 169    Male  78.0   old_age             0              0           No
# 176  Female  81.0   old_age             0              0          Yes
# 178    Male  78.0   old_age             0              0          Yes
# ...

# %% [markdown]
# #### Q6)
# #### c) 150-above

# %%
h=data.loc[(data["work_type"]=="Self-employed")&(data["smoking_status"]=="never smoked")&(data["stroke"]==1)&(data["avg_glucose_level"]>=150)]
h
# Out:
#       gender   age age_group  hypertension  heart_disease ever_married  \
# 3     Female  79.0   old_age             1              0          Yes
# 12    Female  50.0     adult             1              0          Yes
# 17    Female  52.0   old_age             1              0          Yes
# 18    Female  79.0   old_age             0              0          Yes
# 26    Female  82.0   old_age             1              0          Yes
# 46      Male  73.0   old_age             1              0          Yes
# 110   Female  68.0   old_age             1              0          Yes
# 142     Male  72.0   old_age             1              0          Yes
# 4780  Female  61.0   old_age             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 3     Self-employed          Rural             174.12  24.0   never smoked
# 12    Self-employed          Rural             167.41  30.9   never smoked
# ...

# %% [markdown]
# #### 7) Find those age category having brain strock problem

# %%
i=data.loc[(data["stroke"]==1),"age_group"]
i
# Out:
# 0       old_age
# 1       old_age
# 2         adult
# 3       old_age
# 4       old_age
#          ...
# 4815    old_age
# 4816    old_age
# 4817    old_age
# 4818    old_age
# 4819    old_age
# Name: age_group, Length: 248, dtype: object

# %%
i.unique()
# Out:
# array(['old_age', 'adult', 'kid'], dtype=object)

# %%
i.value_counts()
# Out:
# old_age    226
# adult       20
# kid          2
# Name: age_group, dtype: int64

# %%
i.count()
# Out:
# 248
